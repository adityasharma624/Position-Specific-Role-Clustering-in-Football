# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../../../data/raw/FM24.csv')
print("Original columns:\n", df.columns.tolist())
# Out:
# Original columns:
#  ['Name', 'Club', 'Nat', 'Height', 'Weight', 'Age', 'CA', 'PA', 'Acc', 'Agi', 'Bal', 'Jum', 'Nat.1', 'Pac', 'Sta', 'Str', 'Agg', 'Ant', 'Bra', 'Cmp', 'Cnt', 'Dec', 'Det', 'Fla', 'Ldr', 'OtB', 'Pos', 'Tea', 'Vis', 'Wor', 'Cor', 'Cro', 'Dri', 'Fin', 'Fir', 'Fre', 'Hea', 'Lon', 'L Th', 'Mar', 'Pas', 'Pen', 'Tck', 'Tec', 'Acc.1', 'Ant.1', 'Hea.1', 'Jum.1', 'Mar.1', 'Pac.1', 'Pos.1', 'Sta.1', 'Str.1', 'Tck.1', 'Cro.1', 'Dri.1', 'Fre.1', 'Fin.1', 'Fir.1', 'Fla.1', 'Lon.1', 'OtB.1', 'Pas.1', 'Vis.1']

# %%
raw_features = ['Name', 'Club', 'Nat', 'Height', 'Weight', 'Age', 'CA', 'PA', 
'Acc', 'Agi', 'Bal', 'Jum', 'Nat.1', 'Pac', 'Sta', 'Str', 
'Agg', 'Ant', 'Bra', 'Cmp', 'Cnt', 'Dec', 'Det', 'Fla', 
'Ldr', 'OtB', 'Pos', 'Tea', 'Vis', 'Wor', 'Cor', 'Cro', 
'Dri', 'Fin', 'Fir', 'Fre', 'Hea', 'Lon', 
'L Th', 'Mar', 'Pas', 'Pen', 'Tck', 'Tec']
raw_df = df[raw_features].copy()

# %%
cols = [
    'Acc', 'Agi', 'Bal', 'Jum', 'Nat.1', 'Pac', 'Sta', 'Str',
    'Agg', 'Ant', 'Bra', 'Cmp', 'Cnt', 'Dec', 'Det', 'Fla',
    'Ldr', 'OtB', 'Pos', 'Tea', 'Vis', 'Wor', 'Cor', 'Cro',
    'Dri', 'Fin', 'Fir', 'Fre', 'Hea', 'Lon',
    'L Th', 'Mar', 'Pas', 'Pen', 'Tck', 'Tec'
]

num_df = raw_df[cols].copy()

# %%
meta = [
    'Name', 'Club', 'Nat', 'Height', 'Weight', 'Age', 'CA', 'PA'
]

meta_df = raw_df[meta].copy()

# %%
meta_df.to_csv('../../../data/processed/meta_data.csv', index=False)
num_df.to_csv('../../../data/processed/num_data.csv', index=False)
