# %%
import pandas as pd
df = pd.read_csv('../../dataset/raw/FM24.csv')

# %%
metadata_cols = [
    "Name", "Club", "Nat", "Height", "Weight", "Age", "CA", "PA"
]
df_meta = df[metadata_cols].copy()

# %%
df_meta.to_csv('../../dataset/processed/player_metadata.csv', index=False)
