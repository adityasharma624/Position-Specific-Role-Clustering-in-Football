# %%
import pandas as pd
df = pd.read_csv('../dataset/FM24.csv')

# %%
metadata_cols = [
    "Name", "Club", "Nat", "Height", "Weight", "Age", "CA", "PA"
]
df_meta = df[metadata_cols].copy()

# %%
df_meta.to_csv("../dataset/fm24_midfielder_metadata.csv", index=False)
